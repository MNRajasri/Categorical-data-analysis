# %% [markdown]
# # <center> Representation of categorical data </center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\Rajasri\Documents\DATA SCIENCE Naresh IT\Data files\Visadataset - Visadataset.csv")

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - unique (available only in series)
# - nunique
# - value_counts
# - keys
# - index (property)
# - values (property)

# %%
visa_df["education_of_employee"].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
visa_df["education_of_employee"].nunique()
# Out:
# 4

# %%
cdf=visa_df["education_of_employee"].value_counts()

# %%
cdf.keys()
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object', name='education_of_employee')

# %%
cdf.index
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object', name='education_of_employee')

# %%
cdf.values
# Out:
# array([10234,  9634,  3420,  2192], dtype=int64)

# %% [markdown]
# ## <center> 1) Frequency table </center>

# %%
cdf=visa_df["education_of_employee"].value_counts()
cdf
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %% [markdown]
# ## <center> 2) Bar chart </center>

# %% [markdown]
# #### __Method-1__

# %% [markdown]
# - Using matplotlib
#   - by implement with dataframe
#   - as well as list or array

# %%
cdf=visa_df["education_of_employee"].value_counts()
key=cdf.index
value=cdf.values

# %%
plt.figure(figsize=(5,5))
ax=plt.bar(key,value)
plt.title("Bar chart")
plt.xlabel("Education")
plt.ylabel("Count")
plt.bar_label(ax)
plt.show()

# %%
df=pd.DataFrame({"Education":key,"Count":value})
df
# Out:
#      Education  Count
# 0   Bachelor's  10234
# 1     Master's   9634
# 2  High School   3420
# 3    Doctorate   2192

# %%
plt.figure(figsize=(5,5))
ax=plt.bar("Education","Count",data=df)
plt.title("Bar chart")
plt.xlabel("Education")
plt.ylabel("Count")
plt.bar_label(ax)
plt.show()

# %% [markdown]
# #### __Method-2__

# %% [markdown]
# - using seaborn

# %%
plt.figure(figsize=(5,5))
ax=sns.countplot(visa_df,x="education_of_employee",order=key)
ax.bar_label(ax.containers[0])
plt.title("Bar chart")
plt.show()

# %% [markdown]
# #### __Method-3__

# %% [markdown]
# - using value count

# %%
cdf=visa_df["education_of_employee"].value_counts()
key=cdf.index
value=cdf.values

# %%
plt.figure(figsize=(5,5))
ax=cdf.plot(kind="bar")
plt.title("Bar chart")
plt.xlabel("Education")
plt.ylabel("Count")
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# ## <center> 3) Relative frequency table </center>

# %%
cdf=visa_df["education_of_employee"].value_counts(normalize=True)
cdf
# Out:
# education_of_employee
# Bachelor's     0.401648
# Master's       0.378100
# High School    0.134223
# Doctorate      0.086028
# Name: proportion, dtype: float64

# %% [markdown]
# ## <center> 4) Pie chart </center>

# %%
plt.pie(value,labels=key,autopct=f"%0.3f%%",radius=1,startangle=90)
plt.show()

# %%
plt.pie(value,labels=key,autopct=f"%0.3f%%",explode=[*[0.1]*4]) # explode=[0.1,0.1,0.1,0.1]
plt.title("Pie chart")
plt.show()

# %%
plt.pie(value,labels=key,autopct=f"%0.3f%%",radius=2,startangle=90) # explode=[0.1,0.1,0.1,0.1]
plt.show()

# %% [markdown]
# ## <center> Subplot </center>

# %%
plt.figure(figsize=(10,16))

plt.subplot(3,2,1)
ax=plt.bar(key,value)
plt.title("Bar chart")
plt.xlabel("Education")
plt.ylabel("Count")
plt.bar_label(ax)

plt.subplot(3,2,2)
ax=plt.bar("Education","Count",data=df)
plt.title("Bar chart")
plt.xlabel("Education")
plt.ylabel("Count")
plt.bar_label(ax)

plt.subplot(3,2,3)
ax=sns.countplot(visa_df,x="education_of_employee",order=key)
ax.bar_label(ax.containers[0])
plt.title("Bar chart")

plt.subplot(3,2,4)
ax=cdf.plot(kind="bar")
plt.title("Bar chart")
plt.xlabel("Education")
plt.ylabel("Count")
ax.bar_label(ax.containers[0])

plt.subplot(3,2,5)
plt.pie(value,labels=key,autopct=f"%0.3f%%",radius=1,startangle=90)
plt.title("Pie chart")

plt.show()
